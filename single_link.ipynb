# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitra-B-V/Hierarchical-Clustering-Agglomerative-Single-Link/blob/main/single_link.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.cluster.hierarchy as shc
from scipy.spatial.distance import squareform, pdist

# %%
a=np.array([2,2,3,5,5,5,6,7,8,10,12])
b=np.array([2,6,7,2,5,8,6,3,4,6,8])

# %%
point = ['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11']
data = pd.DataFrame({'Point':point, 'a':np.round(a,2), 'b':np.round(b,2)})
data = data.set_index('Point')
data
# Out:
#         a  b
# Point
# P1      2  2
# P2      2  6
# P3      3  7
# P4      5  2
# P5      5  5
# P6      5  8
# P7      6  6
# P8      7  3
# P9      8  4
# P10    10  6
# P11    12  8

# %%
plt.figure(figsize=(8,5))
plt.scatter(data['a'], data['b'], c='r', marker='*')
plt.xlabel('Column a')
plt.ylabel('column b')
plt.title('Scatter Plot of x and y')
for j in data.itertuples():
    plt.annotate(j.Index, (j.a, j.b), fontsize=15)

# %%
dist = pd.DataFrame(squareform(pdist(data[['a', 'b']]), 'euclidean'), columns=data.index.values, index=data.index.values)

# %%
dist
# Out:
#             P1         P2        P3        P4        P5        P6        P7  \
# P1    0.000000   4.000000  5.099020  3.000000  4.242641  6.708204  5.656854
# P2    4.000000   0.000000  1.414214  5.000000  3.162278  3.605551  4.000000
# P3    5.099020   1.414214  0.000000  5.385165  2.828427  2.236068  3.162278
# P4    3.000000   5.000000  5.385165  0.000000  3.000000  6.000000  4.123106
# P5    4.242641   3.162278  2.828427  3.000000  0.000000  3.000000  1.414214
# P6    6.708204   3.605551  2.236068  6.000000  3.000000  0.000000  2.236068
# P7    5.656854   4.000000  3.162278  4.123106  1.414214  2.236068  0.000000
# P8    5.099020   5.830952  5.656854  2.236068  2.828427  5.385165  3.162278
# P9    6.324555   6.324555  5.830952  3.605551  3.162278  5.000000  2.828427
# P10   8.944272   8.000000  7.071068  6.403124  5.099020  5.385165  4.000000
# P11  11.661904  10.198039  9.055385  9.219544  7.615773  7.000000  6.324555
#
#            P8        P9       P10        P11
# P1   5.099020  6.324555  8.944272  11.661904
# P2   5.830952  6.324555  8.000000  10.198039
# P3   5.656854  5.830952  7.071068   9.055385
# P4   2.236068  3.605551  6.403124   9.219544
# P5   2.828427  3.162278  5.099020   7.615773
# P6   5.385165  5.000000  5.385165   7.000000
# P7   3.162278  2.828427  4.000000   6.324555
# P8   0.000000  1.414214  4.242641   7.071068
# P9   1.414214  0.000000  2.828427   5.656854
# P10  4.242641  2.828427  0.000000   2.828427
# P11  7.071068  5.656854  2.828427   0.000000

# %%
plt.figure(figsize=(12,5)) 
plt.title("Dendrogram with Single inkage")  
dend = shc.dendrogram(shc.linkage(data[['a', 'b']], method='single'), labels=data.index)
